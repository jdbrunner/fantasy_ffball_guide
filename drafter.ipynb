# %% [markdown]
# # Fantasy Football Draft Tool

# %% [markdown]
# ## Initialize draft

# %%
# %run draft_initializer.py

# %% [markdown]
# Adjust league point settings (offense) below by setting OffensePoints[KEY]=Value where KEY is one of:
# - 'Passing Yards'
# - 'Passing TD'
# - 'Interception Thrown'
# - 'Sack Taken'
# - 'Rushing Yards'
# - 'Rusing TD'
# - 'Reception'
# - 'Receiving Yards'
# - 'Receiving TD'
# - 'Return Yards'
# - 'Return TD'
# - '2 Point Conversion'
# - 'Fumble'
# - 'Fumble Lost'
#
# Default is Yahoo default point values.

# %%
OffensePoints['Interceptions'] = -1
OffensePoints['Return Yards'] = 1/25
OffensePoints['Fumble'] = -1
OffensePoints['Fumble Lost'] = -1

# %% [markdown]
# Adjust league point settings (defense) below by setting DefensePoints[KEY]=Value where KEY is one of:
# - 'Sack'
# - 'Interception'
# - 'Fumble Recovery'
# - 'Touchdown'
# - 'Safety'
# - 'Blocked Kick'
# - 'Return Touchdown'
# - 'Points Allowed: 0'
# - 'Points Allowed: 1-6'
# - 'Points Allowed: 7-13'
# - 'Points Allowed: 14-20'
# - 'Points Allowed: 21-27'
# - 'Points Allowed: 28-34'
# - 'Points Allowed: 35+'
# - 'Tackle for loss'
# - 'Extra Point Returned'
#
# Default is Yahoo default point values.

# %%
DefensePoints['Touchdown'] = 4
DefensePoints['Tackle for loss'] = 0.5

# %% [markdown]
# Adjust league roster settings below by setting Roster[KEY]=Value where KEY is one of
#
# - 'QB'
# - 'RB'
# - 'WR'
# - 'TE'
# - 'FLEX'
# - 'SUPERFLEX'
# - 'DST'
# - 'K'
# - 'BENCH'
#
# Default is Yahoo default roster

# %%
Roster['SUPERFLEX'] = 1
Roster['K'] = 0

# %% [markdown]
# Set league draft order with list of teams.

# %%
order = ['Nathan','Ryan','Lucas','Vince','Connor','Shayne','Jim','Nick','Dylan','Arthur']

# %% [markdown]
# The following cells build a list of players and collect historical data. Call with scoring='Standard' (default), scoring='Half PPR' or scoring='PPR' as appropriate.

# %%
AllPlayers,Historical,HistoricalPPG = BuildList(scoring = "Half PPR")

# %%
DraftBoard,DraftedPlayers,AvailablePlayers,color_board,round,pick = StartDraft(order, AllPlayers,Roster)

# %% [markdown]
# Add keepers

# %%
# #Nathan
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Latavius Murray','Nathan',10,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Austin Ekeler','Nathan',14,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Marquez Valdes-Scantling','Nathan',15,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Ryan
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Nick Chubb','Ryan',10,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Julian Edelman','Ryan',11,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Baker Mayfield','Ryan',15,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Lucus
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Davante Adams','Lucas',8,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('George Kittle','Lucas',11,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Damien Williams','Lucas',15,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Vince
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Marlon Mack','Vince',11,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Phillip Lindsay','Vince',14,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Calvin Ridley','Vince',15,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Connor
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Michael Thomas','Connor',7,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Tyler Boyd','Connor',14,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('James Conner','Connor',15,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Shayne
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Sterling Shepard','Shayne',9,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('JuJu Smith-Schuster','Shayne',12,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Matt Breida','Shayne',15,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Jim
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Alvin Kamara','Jim',8,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Deshaun Watson','Jim',7,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Patrick Mahomes','Jim',4,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Nick
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Adam Thielen','Nick',5,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Tarik Cohen','Nick',7,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Tyler Lockett','Nick',15,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Dylan
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Robert Woods','Dylan',5,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Aaron Jones','Dylan',8,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('DeSean Jackson','Dylan',15,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Arthur
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Cooper Kupp','Arthur',7,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Tyreek Hill','Arthur',8,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Carson Wentz','Arthur',12,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)

# %% [markdown]
# ## Now make picks!

# %% [markdown]
# Get advice for your pick! Running the next cell will give a "short list" of players to consider drafting.

# %%
ShowBoard(DraftBoard,color_board)

# %% [markdown]
# See the team about to draft.
#
# Make pick by typing into "pick".

# %%
# Pick = "Jimmy Graham"
# DraftBoard,DraftedPlayers,AvailablePlayers,color_board,round,pick =Draft(Pick,DraftBoard,DraftedPlayers,AvailablePlayers,color_board,round,pick,order)

# %%
shortlist(AvailablePlayers,round,pick,order,DraftedPlayers,Roster)
# Out:
#                     Pos Team      Score  Risk Tier        PPG  Avg_Rank  \
# Christian McCaffrey  RB  CAR  85.776721   0.4    1  23.466667       1.0
# Saquon Barkley       RB  NYG  75.311732   0.5    1  20.622222       2.0
# Ezekiel Elliott      RB  DAL  71.788850   1.0    1  19.805556       3.0
# Alvin Kamara         RB   NO  67.800129   1.1    1  18.744444       4.0
# Dalvin Cook          RB  MIN  62.728261   2.2    1  17.983333       5.0
# Patrick Mahomes      QB   KC  48.942143   7.4    4  24.372222      25.0
# Dak Prescott         QB  DAL  28.874070   9.6    8  20.900000      53.0
# Deshaun Watson       QB  HOU  28.692887   9.4    9  19.994444      62.0
# Lamar Jackson        QB  BAL  27.681797  10.1    5  22.111111      27.0
# Kyler Murray         QB  ARI  25.033176  10.2    9  20.405556      59.0
#
#                      Expected PPG Lost  Max PPG Lost  \
# Christian McCaffrey           3.661111     11.533333
# Saquon Barkley                3.661111     11.533333
# ...

# %%
FindCliffs(DraftedPlayers,HistoricalPPG)

# %%
AvailablePlayers
# Out:
#                           Pos Team Rank Positional_Rank Tier      PPG  \
# Christian McCaffrey        RB  CAR    1               1    1  23.4667
# Saquon Barkley             RB  NYG    2               2    1  20.6222
# Ezekiel Elliott            RB  DAL    3               3    1  19.8056
# Alvin Kamara               RB   NO    4               4    1  18.7444
# Dalvin Cook                RB  MIN    5               5    1  17.9833
# Derrick Henry              RB  TEN    6               6    1  17.0778
# Michael Thomas             WR   NO    7               1    1  18.5944
# Clyde Edwards-Helaire      RB   KC    8               7    2  16.6556
# Davante Adams              WR   GB    9               2    2     17.7
# Joe Mixon                  RB  CIN   10               8    2  16.2944
# Julio Jones                WR  ATL   11               3    2    16.65
# Tyreek Hill                WR   KC   12               4    2  16.0556
# ...

# %%
AvailablePlayers[AvailablePlayers.Pos == 'QB']
# Out:
#                    Pos Team Rank Positional_Rank Tier      PPG Best_Rank  \
# Lamar Jackson       QB  BAL   27               2    5  22.1111         6
# Dak Prescott        QB  DAL   53               3    8     20.9        19
# Kyler Murray        QB  ARI   59               4    9  20.4056        19
# Russell Wilson      QB  SEA   63               6    9  19.5167        20
# Josh Allen          QB  BUF   75               7   10  19.1111        31
# Matt Ryan           QB  ATL   76               8   10  18.6444        38
# Carson Wentz        QB  PHI   83               9   11  18.4056        25
# Drew Brees          QB   NO   86              10   12  18.1667        48
# Tom Brady           QB   TB   87              11   12  17.8833        37
# Matthew Stafford    QB  DET   93              12   13  17.5889        36
# Aaron Rodgers       QB   GB  103              13   13  17.3722        24
# Ben Roethlisberger  QB  PIT  114              14   15    17.15        64
# ...

# %%
np.unique(AvailablePlayers.Pos.values)
# Out:
# array(['DST', 'K', 'QB', 'RB', 'TE', 'WR'], dtype=object)

# %%
AvailablePlayers[AvailablePlayers.Pos == 'RB']
# Out:
#                       Pos Team Rank Positional_Rank Tier      PPG Best_Rank  \
# Christian McCaffrey    RB  CAR    1               1    1  23.4667         1
# Saquon Barkley         RB  NYG    2               2    1  20.6222         1
# Ezekiel Elliott        RB  DAL    3               3    1  19.8056         2
# Alvin Kamara           RB   NO    4               4    1  18.7444         2
# Dalvin Cook            RB  MIN    5               5    1  17.9833         2
# Derrick Henry          RB  TEN    6               6    1  17.0778         3
# Clyde Edwards-Helaire  RB   KC    8               7    2  16.6556         4
# Joe Mixon              RB  CIN   10               8    2  16.2944         4
# Miles Sanders          RB  PHI   13               9    2  15.7444         5
# Nick Chubb             RB  CLE   14              10    3  15.1667         5
# Josh Jacobs            RB   LV   15              11    3  14.7833         2
# ...

# %%
AvailablePlayers[AvailablePlayers.Pos == 'WR']
# Out:
#                          Pos Team Rank Positional_Rank Tier      PPG  \
# Michael Thomas            WR   NO    7               1    1  18.5944
# Davante Adams             WR   GB    9               2    2     17.7
# Julio Jones               WR  ATL   11               3    2    16.65
# Tyreek Hill               WR   KC   12               4    2  16.0556
# Chris Godwin              WR   TB   19               5    3  15.5833
# DeAndre Hopkins           WR  ARI   20               6    3  15.1111
# Kenny Golladay            WR  DET   23               7    3  14.7056
# Allen Robinson            WR  CHI   24               8    4     14.5
# Mike Evans                WR   TB   26               9    4  14.1778
# D.J. Moore                WR  CAR   30              10    5  13.9556
# Adam Thielen              WR  MIN   31              11    5  13.6778
# Odell Beckham             WR  CLE   33              12    5  13.4889
# JuJu Smith-Schuster       WR  PIT   34              13    5  13.2167
# ...

# %%
AvailablePlayers[AvailablePlayers.Pos == 'TE']
# Out:
#                  Pos Team Rank Positional_Rank Tier      PPG Best_Rank  \
# Travis Kelce      TE   KC   17               1    3  13.9722         8
# George Kittle     TE   SF   22               2    3  12.3222        11
# Mark Andrews      TE  BAL   44               3    6  11.4167        17
# Zach Ertz         TE  PHI   49               4    7  10.5278        27
# Darren Waller     TE   LV   58               5    8  9.82778        33
# Evan Engram       TE  NYG   72               6   10  9.44444        36
# Hunter Henry      TE  LAC   77               7   11  8.91667        38
# Tyler Higbee      TE  LAR   79               8   11  8.55556        43
# Hayden Hurst      TE  ATL   90               9   13  8.31667        42
# Jared Cook        TE   NO   99              10   13  8.12778        48
# Austin Hooper     TE  CLE  100              11   14  7.81667        60
# Mike Gesicki      TE  MIA  104              12   14  7.54444        53
# ...

# %%
AvailablePlayers[AvailablePlayers.Pos == 'DST']
# Out:
#      Pos Team Rank Positional_Rank Tier      PPG Best_Rank Worst_Rank  \
# SF   DST   SF  157               1   26  10.2556        47        248
# PIT  DST  PIT  162               2   26  9.53333        56        200
# BAL  DST  BAL  164               3   26  9.02778        61        194
# BUF  DST  BUF  168               4   26  8.73889        61        255
# NE   DST   NE  172               5   26  8.37778        55        256
# CHI  DST  CHI  176               6   26  8.13889        59        248
# NO   DST   NO  179               7   26  7.97222        83        220
# KC   DST   KC  185               8   26      7.8        73        293
# MIN  DST  MIN  190               9   26  7.59444        90        276
# LAR  DST  LAR  191              10   26  7.44444        51        290
# DEN  DST  DEN  199              11   26  7.35556        93        293
# PHI  DST  PHI  205              12   26  7.22778       101        253
# ...
