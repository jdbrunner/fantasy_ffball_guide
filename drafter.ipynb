# %% [markdown]
# # Fantasy Football Draft Tool

# %% [markdown]
# ## Initialize draft

# %%
# %run draft_initializer.py

# %% [markdown]
# Adjust league point settings (offense) below by setting OffensePoints[KEY]=Value where KEY is one of:
# - 'Passing Yards'
# - 'Passing TD'
# - 'Interception Thrown'
# - 'Sack Taken'
# - 'Rushing Yards'
# - 'Rusing TD'
# - 'Reception'
# - 'Receiving Yards'
# - 'Receiving TD'
# - 'Return Yards'
# - 'Return TD'
# - '2 Point Conversion'
# - 'Fumble'
# - 'Fumble Lost'
#
# Default is Yahoo default point values.

# %%
OffensePoints['Interceptions'] = -1
OffensePoints['Return Yards'] = 1/25
OffensePoints['Fumble'] = -1
OffensePoints['Fumble Lost'] = -1

# %% [markdown]
# Adjust league point settings (defense) below by setting DefensePoints[KEY]=Value where KEY is one of:
# - 'Sack'
# - 'Interception'
# - 'Fumble Recovery'
# - 'Touchdown'
# - 'Safety'
# - 'Blocked Kick'
# - 'Return Touchdown'
# - 'Points Allowed: 0'
# - 'Points Allowed: 1-6'
# - 'Points Allowed: 7-13'
# - 'Points Allowed: 14-20'
# - 'Points Allowed: 21-27'
# - 'Points Allowed: 28-34'
# - 'Points Allowed: 35+'
# - 'Tackle for loss'
# - 'Extra Point Returned'
#
# Default is Yahoo default point values.

# %%
DefensePoints['Touchdown'] = 4
DefensePoints['Tackle for loss'] = 0.5

# %% [markdown]
# Adjust league roster settings below by setting Roster[KEY]=Value where KEY is one of
#
# - 'QB'
# - 'RB'
# - 'WR'
# - 'TE'
# - 'FLEX'
# - 'SUPERFLEX'
# - 'DST'
# - 'K'
# - 'BENCH'
#
# Default is Yahoo default roster

# %%
Roster['SUPERFLEX'] = 1
Roster['K'] = 0

# %% [markdown]
# Set league draft order with list of teams.

# %%
order = ["Connor","Shayne","Jim","Lucas","Vince","Nathan","Dylan","Nick","Ryan","Arthur"]

# %% [markdown]
# The following cells build a list of players and collect historical data. Call with scoring='Standard' (default), scoring='Half PPR' or scoring='PPR' as appropriate.

# %%
AllPlayers,Historical,HistoricalPPG = BuildList(scoring = "Half PPR")

# %%
DraftBoard,DraftedPlayers,AvailablePlayers,color_board,round,pick = StartDraft(order, AllPlayers,Roster)

# %% [markdown]
# Add keepers

# %%
#Nathan
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Jarvis Landry','Nathan',5,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Duke Johnson','Nathan',10,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Austin Ekeler','Nathan',11,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
#Ryan
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Nick Chubb','Ryan',5,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Devin Singletary','Ryan',11,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('DeVante Parker','Ryan',10,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
#Lucus
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Davante Adams','Lucas',3,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('George Kittle','Lucas',8,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Josh Allen','Lucas',7,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Vince
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Phillip Lindsay','Vince',11,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Calvin Ridley','Vince',12,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
#Connor
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Michael Thomas','Connor',2,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('A.J. Brown','Connor',11,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('James Conner','Connor',12,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Shayne
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('JuJu Smith-Schuster','Shayne',8,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Mark Andrews','Shayne',11,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Kareem Hunt','Shayne',14,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
# #Jim
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Alvin Kamara','Jim',8,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Deshaun Watson','Jim',7,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Patrick Mahomes','Jim',4,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
#Nick
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Tyler Lockett','Nick',12,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
#Dylan
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Kenyan Drake','Dylan',5,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Aaron Jones','Dylan',4,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('D.K. Metcalf','Dylan',11,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
#Arthur
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Darren Waller','Arthur',11,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Tyreek Hill','Arthur',3,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)
DraftBoard,DraftedPlayers,AvailablePlayers,color_board =AddKeep('Carson Wentz','Arthur',8,DraftBoard,DraftedPlayers,AvailablePlayers,color_board)

# %% [markdown]
# ## Now make picks!

# %% [markdown]
# Get advice for your pick! Running the next cell will give a "short list" of players to consider drafting.

# %%
ShowBoard(DraftBoard,color_board)

# %%
for i in range(19):
    Pick = shortlist(AvailablePlayers,round,pick,order,DraftedPlayers,Roster).index[0]
    DraftBoard,DraftedPlayers,AvailablePlayers,color_board,round,pick =Draft(Pick,DraftBoard,DraftedPlayers,AvailablePlayers,color_board,round,pick,order)

# %% [markdown]
# See the team about to draft.
#
# Make pick by typing into "pick".

# %%
Pick = "Christian McCaffrey"
DraftBoard,DraftedPlayers,AvailablePlayers,color_board,round,pick =Draft(Pick,DraftBoard,DraftedPlayers,AvailablePlayers,color_board,round,pick,order)

# %%
shortlist(AvailablePlayers,round,pick,order,DraftedPlayers,Roster)
# Out:
#                    Pos Team     Score  Risk Tier        PPG  Avg_Rank  \
# Jimmy Garoppolo     QB   SF  2.987106  24.0   21  15.088889     149.0
# Philip Rivers       QB  IND  2.901320  31.1   22  14.655556     159.0
# Teddy Bridgewater   QB  CAR  2.868326  33.9   23  14.488889     161.0
# Drew Lock           QB  DEN  2.822134  28.6   22  14.255556     162.0
# Derek Carr          QB   LV  2.780340  40.0   25  14.044444     179.0
# Melvin Gordon       RB  DEN  2.709843   9.0    6  11.933333      43.0
# Leonard Fournette   RB   TB  2.674519  12.8   13  11.777778      47.0
# Mark Ingram         RB  BAL  2.632888  12.5    7  11.594444      49.0
# Raheem Mostert      RB   SF  2.595041  14.9    9  11.427778      55.0
# Cam Akers           RB  LAR  2.535747  26.7    9  11.166667      57.0
# CHI                DST  CHI  1.372994  27.9   27   7.972222     170.0
# KC                 DST   KC  1.343333  27.1   27   7.800000     174.0
# ...

# %%
FindCliffs(DraftedPlayers,HistoricalPPG)

# %%
AvailablePlayers
# Out:
#                           Pos Team Rank Positional_Rank Tier       PPG  \
# Christian McCaffrey        RB  CAR    1               1    1   23.4667
# Saquon Barkley             RB  NYG    2               2    1   20.6222
# Ezekiel Elliott            RB  DAL    3               3    1   19.8056
# Dalvin Cook                RB  MIN    5               5    1   17.9833
# Derrick Henry              RB  TEN    6               6    1   17.0778
# Michael Thomas             WR   NO    7               1    1   18.5944
# Clyde Edwards-Helaire      RB   KC    9               7    2   16.6556
# Joe Mixon                  RB  CIN   10               8    2   16.2944
# Julio Jones                WR  ATL   11               3    2     16.65
# Josh Jacobs                RB   LV   13               9    2   15.7444
# Miles Sanders              RB  PHI   14              10    2   15.1667
# Kenyan Drake               RB  ARI   16              12    2   14.3833
# ...

# %%
AvailablePlayers[AvailablePlayers.Pos == 'QB']
# Out:
#                    Pos Team Rank Positional_Rank Tier      PPG Best_Rank  \
# Patrick Mahomes     QB   KC   24               1    4  24.3722         4
# Lamar Jackson       QB  BAL   27               2    5  22.1111         3
# Dak Prescott        QB  DAL   53               3    8     20.9         8
# Deshaun Watson      QB  HOU   59               4   10  20.4056         9
# Kyler Murray        QB  ARI   60               5   10  19.9944        11
# Russell Wilson      QB  SEA   61               6   10  19.5167        10
# Josh Allen          QB  BUF   73               7   11  19.1111        14
# Matt Ryan           QB  ATL   75               8   11  18.6444        15
# Carson Wentz        QB  PHI   79               9   12  18.4056        20
# Drew Brees          QB   NO   82              10   13  18.1667        26
# Tom Brady           QB   TB   89              11   13  17.8833        19
# Matthew Stafford    QB  DET   90              12   13  17.5889        23
# ...

# %%
AvailablePlayers[AvailablePlayers.Pos == 'RB']
# Out:
#                       Pos Team Rank Positional_Rank Tier      PPG Best_Rank  \
# Christian McCaffrey    RB  CAR    1               1    1  23.4667         1
# Saquon Barkley         RB  NYG    2               2    1  20.6222         1
# Ezekiel Elliott        RB  DAL    3               3    1  19.8056         2
# Alvin Kamara           RB   NO    4               4    1  18.7444         2
# Dalvin Cook            RB  MIN    5               5    1  17.9833         2
# Derrick Henry          RB  TEN    6               6    1  17.0778         2
# Clyde Edwards-Helaire  RB   KC    9               7    2  16.6556         1
# Joe Mixon              RB  CIN   10               8    2  16.2944         4
# Josh Jacobs            RB   LV   13               9    2  15.7444         2
# Miles Sanders          RB  PHI   14              10    2  15.1667         5
# Nick Chubb             RB  CLE   15              11    2  14.7833         6
# ...

# %%
AvailablePlayers[AvailablePlayers.Pos == 'WR']
# Out:
#                          Pos Team Rank Positional_Rank Tier      PPG  \
# Michael Thomas            WR   NO    7               1    1  18.5944
# Davante Adams             WR   GB    9               2    2     17.7
# Julio Jones               WR  ATL   11               3    2    16.65
# Tyreek Hill               WR   KC   12               4    2  16.0556
# Chris Godwin              WR   TB   19               5    3  15.5833
# DeAndre Hopkins           WR  ARI   20               6    3  15.1111
# Kenny Golladay            WR  DET   23               7    3  14.7056
# Allen Robinson            WR  CHI   24               8    4     14.5
# Mike Evans                WR   TB   26               9    4  14.1778
# D.J. Moore                WR  CAR   30              10    5  13.9556
# Adam Thielen              WR  MIN   31              11    5  13.6778
# Odell Beckham             WR  CLE   33              12    5  13.4889
# JuJu Smith-Schuster       WR  PIT   34              13    5  13.2167
# ...

# %%
AvailablePlayers[AvailablePlayers.Pos == 'TE']
# Out:
#                  Pos Team Rank Positional_Rank Tier      PPG Best_Rank  \
# Travis Kelce      TE   KC   17               1    3  13.9722         8
# George Kittle     TE   SF   22               2    3  12.3222        11
# Mark Andrews      TE  BAL   44               3    6  11.4167        17
# Zach Ertz         TE  PHI   49               4    7  10.5278        27
# Darren Waller     TE   LV   58               5    8  9.82778        33
# Evan Engram       TE  NYG   72               6   10  9.44444        36
# Hunter Henry      TE  LAC   77               7   11  8.91667        38
# Tyler Higbee      TE  LAR   79               8   11  8.55556        43
# Hayden Hurst      TE  ATL   90               9   13  8.31667        42
# Jared Cook        TE   NO   99              10   13  8.12778        48
# Austin Hooper     TE  CLE  100              11   14  7.81667        60
# Mike Gesicki      TE  MIA  104              12   14  7.54444        53
# ...

# %%
AvailablePlayers[AvailablePlayers.Pos == 'DST']
# Out:
#      Pos Team Rank Positional_Rank Tier      PPG Best_Rank Worst_Rank  \
# SF   DST   SF  157               1   26  10.2556        47        248
# PIT  DST  PIT  162               2   26  9.53333        56        200
# BAL  DST  BAL  164               3   26  9.02778        61        194
# BUF  DST  BUF  168               4   26  8.73889        61        255
# NE   DST   NE  172               5   26  8.37778        55        256
# CHI  DST  CHI  176               6   26  8.13889        59        248
# NO   DST   NO  179               7   26  7.97222        83        220
# KC   DST   KC  185               8   26      7.8        73        293
# MIN  DST  MIN  190               9   26  7.59444        90        276
# LAR  DST  LAR  191              10   26  7.44444        51        290
# DEN  DST  DEN  199              11   26  7.35556        93        293
# PHI  DST  PHI  205              12   26  7.22778       101        253
# ...
